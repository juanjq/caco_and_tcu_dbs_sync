# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import os
import pymongo
from datetime import datetime
import datetime as dt
import pickle
import json

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
    
def get_records(mongo_client, database_name, collection_name, query):
    collection = mongo_client[database_name][collection_name]
    response   = collection.find(query)
    records = tuple(doc for doc in response)    
    return records

def round_s(obj):
    if (obj.second + obj.microsecond * 1e-6) % 10 >= 5:
        
        obj = obj.replace(second = (obj.second // 10 ) * 10 )
        obj += dt.timedelta(seconds=10)
    else:
        obj = obj.replace(second = (obj.second // 10 ) * 10 )
    obj = obj.replace(microsecond=0)
    return obj

path_caco_runwise = "/home/juan/Desktop/database_migration/caco_run_information"
query = None

read_db = False
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%time
if read_db:
    
    # Reading TCU database
    client_tcu  = pymongo.MongoClient('localhost:27017')
    records_tcu  = get_records(client_tcu,  'lst1_obs_summary', 'camera', query)

    # Reading CaCo database
    client_caco = pymongo.MongoClient('localhost:27018')
    records_caco = get_records(client_caco, 'CACO', 'RUN_INFORMATION', query)

    # Reading CaCo Run-wise database
    dirs_caco_runwise = np.sort(glob.glob(f"{path_caco_runwise}/*"))
    records_caco_runwise = []
    for d in dirs_caco_runwise:
        with open(d) as file:
            dict = json.load(file)
        records_caco_runwise.append(dict)    
    
    # Saving the objects
    with open('objects/records_tcu.pkl', 'wb') as f:
        pickle.dump(records_tcu, f, pickle.HIGHEST_PROTOCOL)
    with open('objects/records_caco.pkl', 'wb') as f:
        pickle.dump(records_caco, f, pickle.HIGHEST_PROTOCOL)
    with open('objects/records_caco_runwise.pkl', 'wb') as f:
        pickle.dump(records_caco_runwise, f, pickle.HIGHEST_PROTOCOL)

else:
    
    # Reading the saved objects
    with open('objects/records_tcu.pkl', 'rb') as f:
        records_tcu = pickle.load(f)
    with open('objects/records_caco.pkl', 'rb') as f:
        records_caco = pickle.load(f)
    with open('objects/records_caco_runwise.pkl', 'rb') as f:
        records_caco_runwise = pickle.load(f)
# Out:
# CPU times: user 549 ms, sys: 414 ms, total: 963 ms
# Wall time: 1.3 s

# %%
# extracting dates of the databases
tstart_tcu          = [datetime.utcfromtimestamp(r["tstart"])       for r in records_tcu]
tstart_caco         = [datetime.fromisoformat(r["start_time"][:-1]) for r in records_caco]
tstart_caco_runwise = [datetime.fromisoformat(r["start_time"][:-1]) for r in records_caco_runwise]

tstop_tcu          = [datetime.utcfromtimestamp(r["tstop"])       for r in records_tcu]
tstop_caco         = [datetime.fromisoformat(r["stop_time"][:-1]) for r in records_caco]
tstop_caco_runwise = [datetime.fromisoformat(r["stop_time"][:-1]) for r in records_caco_runwise]

# Finding the last run number, it should be in CaCo
run_num_caco = [r["run_number"] for r in records_caco]
run_num_caco_runwise = [r["run_number"] for r in records_caco_runwise]
run_num_tcu = []
for r in records_tcu:
    try:
        run_num_tcu.append(r["run_number"])
    except KeyError:
        run_num_tcu.append(None)

higher_run_num = max(max(run_num_caco), max(run_num_caco_runwise))

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(17, 6), sharex=True)

perc_tcu = f", {len(run_num_tcu)/higher_run_num*100:.2f}% of tot"
perc_caco_runwise = f", {len(run_num_caco_runwise)/higher_run_num*100:.2f}% of tot"
perc_caco =  f", {len(run_num_caco)/higher_run_num*100:.2f}% of tot"

ax1.plot(tstart_tcu, np.repeat(2, len(tstart_tcu)), ".", c="darkblue", label=f"TCU --> {len(records_tcu):6} entries" + perc_tcu)
ax1.plot(tstart_caco_runwise, np.repeat(1, len(tstart_caco_runwise)), ".", c="deepskyblue", label=f"CaCo run-wise --> {len(records_caco_runwise):6} entries" + perc_caco_runwise)
ax1.plot(tstart_caco, np.repeat(0, len(tstart_caco)), ".", c="crimson", label=f"CaCo --> {len(records_caco):6} entries" + perc_caco)

ax2.plot(tstart_tcu, run_num_tcu, "o", ms=2, c="darkblue", label=f"TCU", zorder=10)
ax2.plot(tstart_caco_runwise, run_num_caco_runwise, "o", ms=12, c="deepskyblue", label="CaCo run-wise")
ax2.plot(tstart_caco, run_num_caco, "o", ms=5,  c="crimson", label="CaCo")

ax1.legend(loc=2)
ax2.legend(loc=2)
ax1.set_yticks([])
ax1.set_ylim([-0.5, 2.5])
ax1.set_title(f"Last run number {higher_run_num}")
ax2.set_ylabel("Run number")
fig.tight_layout()
plt.show()

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(17, 3), sharex=True)

ax1.plot(tstart_tcu, np.repeat(2, len(tstart_tcu)), ".", c="darkblue", label=f"TCU database")
ax1.plot(tstart_caco_runwise, np.repeat(1, len(tstart_caco_runwise)), ".", c="deepskyblue", label=f"CaCo files")
ax1.plot(tstart_caco, np.repeat(0, len(tstart_caco)), ".", c="crimson", label=f"CaCo database")

ax1.legend(loc=2)
ax1.set_yticks([])
ax1.set_ylim([-0.5, 2.5])
fig.tight_layout()
plt.show()

# %%
min(tstart_caco_runwise), min(tstart_caco)
# Out:
# (datetime.datetime(2020, 6, 16, 23, 31, 5, 393000),
#  datetime.datetime(2020, 7, 3, 8, 33, 48, 815000))

# %%
for rec in records_tcu:
    try:
        rec["run_number"]
    except KeyError:
        rec["run_number"] = np.nan

# %%
filtered_runs = []
t_tcu, t_c, t_c_r = [], [], []
tt_tcu, tt_c, tt_c_r = [], [], []
for r in run_num_caco:
    
    if r in run_num_caco_runwise and r in run_num_tcu:
        
        t_c.append(datetime.fromisoformat([rr for rr in records_caco if rr["run_number"] == r][0]["start_time"][:-1]))
        t_c_r.append(datetime.fromisoformat([rr for rr in records_caco_runwise if rr["run_number"] == r][0]["start_time"][:-1]))
        t_tcu.append(datetime.utcfromtimestamp([rr for rr in records_tcu if rr["run_number"] == r][0]["tstart"]))
        tt_c.append(datetime.fromisoformat([rr for rr in records_caco if rr["run_number"] == r][0]["stop_time"][:-1]))
        tt_c_r.append(datetime.fromisoformat([rr for rr in records_caco_runwise if rr["run_number"] == r][0]["stop_time"][:-1]))
        tt_tcu.append(datetime.utcfromtimestamp([rr for rr in records_tcu if rr["run_number"] == r][0]["tstop"]))
        filtered_runs.append(r)

# %%
delta_cc_start = [(a1 - a2).total_seconds() for a1, a2 in zip(t_c, t_c_r)]
delta_cc_stop  = [(a1 - a2).total_seconds() for a1, a2 in zip(tt_c, tt_c_r)]
print(f"sum(times_caco - times_caco_runwise) = {np.sum(np.abs(delta_cc_start))}")
delta_start = np.array([(a2 - a1).total_seconds() for a1, a2 in zip(t_c, t_tcu)])
print(f"sum(times_caco - times_caco_runwise) = {np.sum(np.abs(delta_cc_stop))}")
delta_stop = np.array([(a2 - a1).total_seconds() for a1, a2 in zip(tt_c, tt_tcu)])


fig, (ax, ax2) = plt.subplots(2, 1, figsize=(10, 8))
ax.hist(delta_start, bins=np.linspace(0, 4, 100), color="crimson")

ax.set_xlabel("$\\Delta t$ (t_tcu - t_caco) [s]")
ax.set_ylabel("Counts")
ax.set_title("Start times $\Delta$")

ax2.hist(delta_stop, bins=np.linspace(-45, -10, 100), color="darkblue")

ax2.set_xlabel("$\\Delta t$ (t_tcu - t_caco) [s]")
ax2.set_ylabel("Counts")
ax2.set_title("Stop times $\Delta$")

fig.tight_layout()
plt.show()
# Out:
# sum(times_caco - times_caco_runwise) = 151303.802
# sum(times_caco - times_caco_runwise) = 151568.748

# %%
records_caco[0]
# Out:
# {'_id': ObjectId('5efeedbe0816476470c34201'),
#  'run_number': 2164,
#  'start_time': '2020-07-03T08:33:48.815Z',
#  'stop_time': '2020-07-03T08:35:10.439Z',
#  'tib': {'DigitalPedestalConfigRate': 0,
#   'AnalogPedestalEnable': False,
#   'PedestalRate': 0.0,
#   'CameraRate': 0.0,
#   'FakeTriggerEnable': False,
#   'PeriodicPedestalFrequency': 0,
#   'PedestalEnable': False,
#   'PeriodicPedestalEnable': False,
#   'valid': True,
#   'LocalRate': 2014.0,
#   'SoftwareTriggerEnable': False,
#   'DelayLocal': 0.0,
#   'SlowControlEnable': False,
#   'CalibrationRate': 0.0,
#   'MonoEnable': False,
#   'BUSYRate': 0.0,
#   'CollectedRate': 0.0,
#   'InputMask': 0,
#   'CalibrationEnable': False,
#   'DigitalPedestalEnable': False,
#   'AnalogPedestalThreshold': 0.0,
#   'SoftwareTriggerRate': 0.0},
#  'cbox': {'valid': True,
#   'hz': 'No available',
#   'wheel1_position': 'No available',
#   'temperature': 'No available',
#   'duty': 'No available',
#   'humidity': 'No available',
#   'wheel2_position': 'No available',
#   'cycles': 'No available'}}

# %%
records_tcu[1000]
# Out:
# {'_id': ObjectId('6262309de36ca5beadadc38b'),
#  'tstart': 1650601516.9665966,
#  'tstop': 1650602113.114972,
#  'kind': 'data_taking',
#  'config': {'camera': 'data_taking_auto',
#   'caco': [{'name': 'bypass_bps',
#     'data': "<?xml version='1.0' encoding='UTF-8'?>\n<module id='CLUS'>\n</module>\n",
#     'application_time': 1650601385.7353299},
#    {'name': 'set_hv_all_dark',
#     'data': "<?xml version='1.0' encoding='UTF-8'?>\n<module id='CLUS'>\n<cluster id='1'><setHV value='[990.89,1107.62,1052.94,1133.54,995.23,1051.36,1024.75]'/></cluster>\n<cluster id='2'><setHV value='[1096.34,1068.13,1095.32,1026.26,1094.28,1003.15,1038.57]'/></cluster>\n<cluster id='3'><setHV value='[1012.75,1079.28,1014.05,987.64,1022.68,1009.38,1046.47]'/></cluster>\n<cluster id='4'><setHV value='[1037.83,1105.19,995.27,1089.63,1062.51,995.02,1057.25]'/></cluster>\n<cluster id='5'><setHV value='[1007.50,1051.05,1115.82,985.18,1043.20,1030.94,1015.63]'/></cluster>\n<cluster id='6'><setHV value='[1042.99,1067.12,1104.74,987.89,1049.78,1016.71,1054.59]'/></cluster>\n<cluster id='7'><setHV value='[1106.04,1170.62,1021.69,1128.97,1073.89,1186.27,1118.82]'/></cluster>\n<cluster id='8'><setHV value='[1112.33,1092.37,1064.45,1008.92,1092.54,1087.20,1049.98]'/></cluster>\n<cluster id='9'><setHV value='[1074.69,1077.94,1010.92,1089.34,1010.87,1108.32,1017.78]'/></cluster>\n<cluster id='10'><setHV value='[1066.78,1069.80,1038.17,1129.10,1079.10,1040.72,1048.31]'/></cluster>\n<cluster id='11'><setHV value='[1059.83,1125.72,1100.53,1126.70,1007.50,1058.04,1034.07]'/></cluster>\n<cluster id='12'><setHV value='[1031.19,1010.36,1098.40,1033.98,1083.55,1088.36,1077.59]'/></cluster>\n<cluster id='13'><setHV value='[1110.14,970.68,1057.74,1020.70,1031.34,953.05,1036.43]'/></cluster>\n<cluster id='14'><setHV value='[1025.14,1061.00,1018.90,1055.64,1084.91,1002.61,1018.75]'/></cluster>\n<cluster id='15'><setHV value='[1067.27,1037.72,1009.48,1136.27,1116.16,982.26,1133.12]'/></cluster>\n<cluster id='16'><setHV value='[1092.03,1126.19,983.08,1069.02,1090.63,1068.15,1078.46]'/></cluster>\n<cluster id='17'><setHV value='[1092.68,1043.24,1071.42,1067.00,1129.88,1000.41,1083.40]'/></cluster>\n<cluster id='18'><setHV value='[1153.65,1172.60,1000.74,1051.00,1041.28,1150.59,1103.60]'/></cluster>\n<cluster id='19'><setHV value='[1058.20,1004.90,1034.37,994.38,1081.42,1066.09,1022.76]'/></cluster>\n<cluster id='20'><setHV value='[1146.63,1033.99,1118.47,1094.98,1045.67,1057.01,1176.70]'/></cluster>\n<cluster id='21'><setHV value='[1041.50,1110.39,1076.39,1005.76,1067.99,1019.70,1024.89]'/></cluster>\n<cluster id='22'><setHV value='[1049.53,1197.76,1024.23,1012.09,1137.79,1079.89,1143.54]'/></cluster>\n<cluster id='23'><setHV value='[1027.81,1153.19,1004.68,1130.60,1080.67,1118.70,1054.49]'/></cluster>\n<cluster id='24'><setHV value='[1044.10,1076.62,1054.53,1194.35,1113.82,993.45,1004.96]'/></cluster>\n<cluster id='25'><setHV value='[1068.42,1011.88,1093.40,1131.96,1038.57,977.94,1080.00]'/></cluster>\n<cluster id='26'><setHV value='[1077.20,985.88,1059.36,996.05,1028.60,1050.21,1088.70]'/></cluster>\n<cluster id='27'><setHV value='[1166.39,1159.27,1148.02,1028.84,1114.93,1024.68,1163.61]'/></cluster>\n<cluster id='28'><setHV value='[1063.22,985.04,981.38,1030.90,1064.92,993.77,1069.34]'/></cluster>\n<cluster id='29'><setHV value='[1088.57,1048.17,1109.80,1037.99,1127.40,1143.62,1047.64]'/></cluster>\n<cluster id='30'><setHV value='[1155.81,1045.54,1006.50,1061.02,1058.67,1057.85,1006.78]'/></cluster>\n<cluster id='31'><setHV value='[1162.04,969.60,1113.98,1089.33,1007.35,1008.66,958.40]'/></cluster>\n<cluster id='32'><setHV value='[1142.84,985.76,990.93,1007.73,1015.68,999.71,1013.36]'/></cluster>\n<cluster id='33'><setHV value='[1022.21,1095.47,1146.62,1119.58,1124.53,1103.35,1125.04]'/></cluster>\n<cluster id='34'><setHV value='[1051.44,1139.55,1084.35,1144.55,1095.52,1120.62,1039.68]'/></cluster>\n<cluster id='35'><setHV value='[1117.99,1106.30,1074.89,1150.66,1145.50,1070.10,1109.87]'/></cluster>\n<cluster id='36'><setHV value='[1024.49,998.40,1028.47,1014.98,1016.40,1035.90,1090.48]'/></cluster>\n<cluster id='37'><setHV value='[1052.68,1105.49,1071.60,1154.16,1105.43,1055.72,1055.63]'/></cluster>\n<cluster id='38'><setHV value='[1068.74,1070.17,1052.31,1067.49,1010.93,982.00,994.09]'/></cluster>\n<cluster id='39'><setHV value='[998.50,1089.05,10 ...
#     'application_time': 1650601387.766284}],
#   'cbox': {'wheel_positions': [5, 2],
#    'laser_freq': 100,
#    'laser_cycles': 100000000}},
#  'health': {'local_rate': {'min': 1545.0,
#    'mean': 1633.3636363636363,
#    'max': 1741.0},
#   'anode_current': {'min': 35.248321533203125,
#    'mean': 35.74336051298713,
#    'max': 36.13858413696289}},
#  'run_number': nan}

# %%
for i in range(len(filtered_runs)):
    if delta_cc_stop[i] < 0:
        print(filtered_runs[i])
# Out:
# 14147
# 14147

# %%
rec1, rec2 = [r for r in records_caco if r["run_number"] == 14147]
rect      = [r for r in records_tcu if r["run_number"] == 14147]
rec1, rec2, rect
# Out:
# ({'_id': ObjectId('64f7b45246e0fb000a993470'),
#   'is_test': False,
#   'run_number': 14147,
#   'start_time': '2023-09-05T23:04:30.034Z',
#   'stop_time': '2023-09-05T23:05:54.110Z',
#   'tib': {'TIB_Rates_LocalRate': 1953.0,
#    'TIB_Pedestal_PeriodicPedestalFrequency': 0,
#    'TIB_TriggerMode_SlowControlEnable': False,
#    'TIB_TriggerMode_CalibrationEnable': False,
#    'TIB_Delays_DelayLocal': 0.0,
#    'TIB_Pedestal_PeriodicPedestalEnable': False,
#    'TIB_Rates_BUSYRate': 0.0,
#    'TIB_Pedestal_Fake_trig_enable': False,
#    'TIB_TriggerMode_MonoEnable': False,
#    'TIB_Pedestal_AnalogPedestalThreshold': 0.0,
#    'TIB_Pedestal_AnalogPedestalEnable': False,
#    'TIB_InputsEnable_InputMask': 0,
#    'valid': True,
#    'TIB_Rates_SoftrigRate': 0.0,
#    'TIB_Rates_CameraRate': 0.0,
#    'TIB_TriggerMode_PedestalEnable': False,
#    'TIB_Pedestal_DigitalPedestal_config_Rate': 0,
#    'TIB_Rates_CalibrationRate': 13.0,
#    'TIB_Pedestal_DigitalPedestalEnable': False,
#    'TIB_Rates_PedestalRate': 0.0,
#    'TIB_TriggerMode_SoftwareTrigEnable': False,
#    'TIB_Rates_CollectedRate': 0.0},
#   'cbox': {'valid': True,
#    'CBOX_Temperature': 'No available',
#    'CBOX_LaserTrigParameters1': 'No available',
#    'CBOX_Humidity': 'No available',
#    'CBOX_WheelPosition2': 'No available',
#    'CBOX_WheelPosition1': 'No available',
#    'CBOX_LaserTrigParameters2': 'No available'}},
#  {'_id': ObjectId('64f8dc5a46e0fb00099a3b94'),
#   'is_test': False,
#   'run_number': 14147,
#   'start_time': '2023-09-06T20:05:21.935Z',
#   'stop_time': '2023-09-06T20:08:58.484Z',
#   'tib': {'TIB_Rates_LocalRate': 1953.0,
#    'TIB_Pedestal_PeriodicPedestalFrequency': 0,
#    'TIB_TriggerMode_SlowControlEnable': False,
#    'TIB_TriggerMode_CalibrationEnable': False,
#    'TIB_Delays_DelayLocal': 0.0,
#    'TIB_Pedestal_PeriodicPedestalEnable': False,
#    'TIB_Rates_BUSYRate': 0.0,
#    'TIB_Pedestal_Fake_trig_enable': False,
#    'TIB_TriggerMode_MonoEnable': False,
#    'TIB_Pedestal_AnalogPedestalThreshold': 0.0,
#    'TIB_Pedestal_AnalogPedestalEnable': False,
#    'TIB_InputsEnable_InputMask': 0,
#    'valid': True,
#    'TIB_Rates_SoftrigRate': 0.0,
#    'TIB_Rates_CameraRate': 0.0,
#    'TIB_TriggerMode_PedestalEnable': False,
#    'TIB_Pedestal_DigitalPedestal_config_Rate': 0,
#    'TIB_Rates_CalibrationRate': 9.0,
#    'TIB_Pedestal_DigitalPedestalEnable': False,
#    'TIB_Rates_PedestalRate': 0.0,
#    'TIB_TriggerMode_SoftwareTrigEnable': False,
#    'TIB_Rates_CollectedRate': 0.0},
#   'cbox': {'valid': True,
#    'CBOX_Temperature': 'No available',
#    'CBOX_LaserTrigParameters1': 'No available',
#    'CBOX_Humidity': 'No available',
#    'CBOX_WheelPosition2': 'No available',
#    'CBOX_WheelPosition1': 'No available',
#    'CBOX_LaserTrigParameters2': 'No available'}},
#  [{'_id': ObjectId('64f7b45239f43121f14977de'),
#    'run_number': 14147,
#    'tstart': 1693955070.2189465,
#    'tstop': 1693955120.4755332,
#    'kind': 'calib_drs4',
#    'config': {'camera': 'drs4_calib',
#     'caco': [{'name': 'start_random_trigger',
#       'data': "<?xml version='1.0' encoding='UTF-8'?>\n<module id='CLUS'>\n<startRandomTrigger value='2000'/>\n</module>",
#       'application_time': 1693955055.4515154}],
#     'cbox': {}},
#    'health': {'local_rate': {'min': 1918.0, 'mean': 1989.96, 'max': 2072.0},
#     'anode_current': {'min': 0.0, 'mean': 0.0, 'max': 0.0}}}])

# %%
rt1, rt2 = datetime.fromisoformat(rec1["start_time"][:-1]), datetime.fromisoformat(rec2["start_time"][:-1])
rtt, rttype = rect[0]["tstart"], rect[0]["kind"]
print(f"Run 14147-1:\n{rt1}\n{rt2}")
print(f"\nTCU timestamp:\n{datetime.utcfromtimestamp(rtt)} --> {rttype}")
# Out:
# Run 14147-1:
# 2023-09-05 23:04:30.034000
# 2023-09-06 20:05:21.935000
#
# TCU timestamp:
# 2023-09-05 23:04:30.218946 --> calib_drs4

# %%
N = 80

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(7, 7), sharex="col", sharey="row", gridspec_kw={'height_ratios': [1, 2], 'width_ratios': [2, 1]})

ax1.hist(delta_start, np.linspace(0, 3, N), color="crimson")
ax4.hist(delta_stop, np.linspace(-40, -15, N), color="darkblue", orientation="horizontal")
ax3.hist2d(delta_start, delta_stop, bins=(np.linspace(0, 3, N), np.linspace(-40, -15, N)))


fig.delaxes(ax2)
plt.subplots_adjust(wspace=0, hspace=0)
ax1.set_ylabel("Counts")
ax4.set_xlabel("Counts")
ax3.set_ylabel("Start $\\Delta t$ (t_tcu - t_caco) [s]")
ax3.set_xlabel("Stop $\\Delta t$ (t_tcu - t_caco) [s]")
plt.show()

# %%
N=80

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(13, 7), sharex="col", sharey="row", gridspec_kw={'width_ratios': [2, 0.6]})

ax1.hist2d([t.timestamp() for t in t_c], delta_start, bins=(N, np.linspace(0, 3.5, N)))
ax3.hist2d([t.timestamp() for t in t_c], delta_stop, bins=(N, np.linspace(-45, -10, N)))

ax2.hist(delta_start, np.linspace(0, 3, N), color="crimson", orientation="horizontal")
ax4.hist(delta_stop, np.linspace(-40, -15, N), color="darkblue", orientation="horizontal")

plt.subplots_adjust(wspace=0)
ax4.set_xlabel("Counts")
ax1.set_ylabel("Start $\\Delta t$ (t_tcu - t_caco) [s]")
ax3.set_ylabel("Stop $\\Delta t$ (t_tcu - t_caco) [s]")
ax2.set_xscale("log")
ax4.set_xscale("log")
ticks = ax3.get_xticks()
ax3.set_xticklabels([str(datetime.utcfromtimestamp(t))[:-12] for t in ticks])
ax3.set_xlim([np.min(t_c).timestamp(), np.max(t_c).timestamp()])
plt.show()
# Out:
# /tmp/ipykernel_45513/3305553033.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels([str(datetime.utcfromtimestamp(t))[:-12] for t in ticks])

# %%
for i in range(len(records_caco[:])):
    
    rec = records_caco[i]
    run_1 = rec["run_number"]
    if run_1 == 0 or run_1 == 1:
        stime = datetime.fromisoformat(rec["start_time"][:-1]).replace(microsecond=0)
        
        tstart, tstop = datetime.fromisoformat(rec["start_time"][:-1]), datetime.fromisoformat(rec["stop_time"][:-1])
        delta = (tstop - tstart).total_seconds()/60
        a, b = records_caco[i-1]["run_number"], records_caco[i+1]["run_number"]
        print(f"\nFor run from {stime}:\nrun_id = {run_1}\nbefore/after run: {a}/{b}\nlasted = {delta:.1f} min")
# Out:
# For run from 2020-07-22 02:57:24:
# run_id = 0
# before/after run: 2295/1
# lasted = 4.1 min
#
# For run from 2020-07-22 03:16:34:
# run_id = 1
# before/after run: 0/0
# lasted = 3.3 min
#
# For run from 2020-07-22 03:26:33:
# run_id = 0
# before/after run: 1/1
# lasted = 3.4 min
#
# For run from 2020-07-22 03:35:26:
# run_id = 1
# before/after run: 0/0
# lasted = 1.6 min
#
# For run from 2020-07-22 03:48:02:
# run_id = 0
# before/after run: 1/1
# lasted = 16.1 min
#
# For run from 2020-07-22 04:09:41:
# run_id = 1
# before/after run: 0/0
# lasted = 0.4 min
#
# For run from 2020-07-22 04:12:38:
# run_id = 0
# before/after run: 1/1
# lasted = 23.3 min
#
# For run from 2020-07-22 04:39:40:
# run_id = 1
# before/after run: 0/0
# lasted = 0.7 min
#
# For run from 2020-07-22 04:43:41:
# run_id = 0
# before/after run: 1/2296
# lasted = 3.7 min
#
# For run from 2020-11-13 03:29:56:
# run_id = 0
# before/after run: 2899/1
# lasted = 8.3 min
#
# For run from 2020-11-13 03:45:13:
# run_id = 1
# before/after run: 0/0
# lasted = 11.2 min
#
# For run from 2020-11-13 04:05:18:
# run_id = 0
# before/after run: 1/1
# lasted = 4.9 min
#
# For run from 2020-11-13 04:11:56:
# run_id = 1
# before/after run: 0/2900
# lasted = 16.9 min
#
# For run from 2020-12-21 04:40:16:
# run_id = 0
# before/after run: 3364/1
# lasted = 6.2 min
#
# For run from 2020-12-21 04:48:50:
# run_id = 1
# before/after run: 0/0
# lasted = 1.9 min
#
# For run from 2020-12-21 04:58:21:
# run_id = 0
# before/after run: 1/1
# lasted = 7.9 min
#
# For run from 2020-12-21 05:11:17:
# run_id = 1
# before/after run: 0/3365
# lasted = 31.1 min
#
# For run from 2021-03-10 04:52:41:
# run_id = 0
# before/after run: 3926/1
# lasted = 4.4 min
#
# For run from 2021-03-10 04:58:43:
# run_id = 1
# before/after run: 0/3927
# lasted = 31.7 min
#
# For run from 2021-03-16 05:09:34:
# run_id = 0
# before/after run: 4077/1
# lasted = 7.2 min
#
# For run from 2021-03-16 05:20:27:
# run_id = 1
# before/after run: 0/0
# lasted = 2.9 min
#
# For run from 2021-03-16 05:41:26:
# run_id = 0
# before/after run: 1/1
# lasted = 0.8 min
#
# For run from 2021-03-16 05:43:16:
# run_id = 1
# before/after run: 0/4078
# lasted = 7.7 min
#
# For run from 2021-05-05 10:10:16:
# run_id = 1
# before/after run: 4607/0
# lasted = 6.3 min
#
# For run from 2021-05-05 10:26:38:
# run_id = 0
# before/after run: 1/1
# lasted = 4.7 min
#
# For run from 2021-05-05 10:32:20:
# run_id = 1
# before/after run: 0/0
# lasted = 6.7 min
#
# For run from 2021-05-05 10:40:03:
# run_id = 0
# before/after run: 1/4608
# lasted = 13.4 min
#
# For run from 2021-12-01 13:42:24:
# run_id = 0
# before/after run: 6605/1
# lasted = 4.0 min
#
# For run from 2021-12-01 14:33:37:
# run_id = 1
# before/after run: 0/0
# lasted = 4.0 min
#
# For run from 2021-12-01 14:40:30:
# run_id = 0
# before/after run: 1/1
# lasted = 6.4 min
#
# For run from 2021-12-01 14:58:33:
# run_id = 1
# before/after run: 0/6607
# lasted = 19.0 min
#
# For run from 2021-12-14 14:35:53:
# run_id = 0
# before/after run: 6646/1
# lasted = 26.9 min
#
# For run from 2021-12-14 15:05:30:
# run_id = 1
# before/after run: 0/0
# lasted = 24.4 min
#
# For run from 2021-12-14 15:51:28:
# run_id = 0
# before/after run: 1/1
# lasted = 6.0 min
#
# For run from 2021-12-14 16:01:06:
# run_id = 1
# before/after run: 0/6648
# lasted = 15.5 min
#
# For run from 2022-01-12 17:43:22:
# run_id = 1
# before/after run: 6674/0
# lasted = 10.5 min
#
# For run from 2022-01-12 17:56:38:
# run_id = 0
# before/after run: 1/1
# lasted = 7.1 min
#
# For run from 2022-01-12 18:07:28:
# run_id = 1
# before/after run: 0/6675
# lasted = 2.4 min
#
# For run from 2022-01-18 15:09:31:
# run_id = 0
# before/after run: 6697/1
# lasted = 18.9 min
#
# For run from 2022-01-18 15:30:38:
# run_id = 1
# before/after run: 0/0
# lasted = 5.4 min
#
# For run from 2022-01-18 15:40:57:
# run_id = 0
# before/after run: 1/1
# lasted = 2.2 min
#
# For run from 2022-01-18 15:45:04:
# run_id = 1
# before/after run: 0/0
# lasted = 1.4 min
#
# For run from 2022-01-18 15:49:35:
# run_id = 0
# before/after run: 1/1
# lasted = 20.4 min
#
# For run from 2022-01-18 16:11:38:
# run_id = 1
# before/after run: 0/0
# lasted = 9.9 min
#
# For run from 2022-01-18 16:26:04:
# run_id = 0
# before/after run: 1/1
# lasted = 1.8 min
#
# For run from 2022-01-18 17:11:26:
# run_id = 1
# before/after run: 0/0
# lasted = 3.4 min
#
# For run from 2022-01-18 17:17:44:
# run_id = 0
# before/after run: 1/1
# lasted = 9.9 min
#
# For run from 2022-01-18 17:29:33:
# run_id = 1
# before/after run: 0/0
# lasted = 15.6 min
#
# For run from 2022-01-18 17:46:49:
# run_id = 0
# before/after run: 1/1
# lasted = 9.8 min
#
# For run from 2022-01-18 17:57:38:
# run_id = 1
# before/after run: 0/0
# lasted = 21.5 min
#
# For run from 2022-01-18 18:20:47:
# run_id = 0
# before/after run: 1/6698
# lasted = 5.4 min
#
# For run from 2022-01-21 12:09:41:
# run_id = 1
# before/after run: 6702/0
# lasted = 11.4 min
#
# For run from 2022-01-21 12:22:15:
# run_id = 0
# before/after run: 1/1
# lasted = 5.2 min
#
# For run from 2022-01-21 12:28:18:
# run_id = 1
# before/after run: 0/0
# lasted = 10.2 min
#
# For run from 2022-01-21 12:41:33:
# run_id = 0
# before/after run: 1/1
# lasted = 2.5 min
#
# For run from 2022-01-21 12:46:30:
# run_id = 1
# before/after run: 0/0
# lasted = 2.1 min
#
# For run from 2022-01-21 12:52:17:
# run_id = 0
# before/after run: 1/1
# lasted = 12.2 min
#
# For run from 2022-01-21 13:09:39:
# run_id = 1
# before/after run: 0/0
# lasted = 55.4 min
#
# For run from 2022-01-21 15:57:06:
# run_id = 0
# before/after run: 1/1
# lasted = 0.3 min
#
# For run from 2022-01-21 16:00:48:
# run_id = 1
# before/after run: 0/0
# lasted = 14.2 min
#
# For run from 2022-01-21 16:15:59:
# run_id = 0
# before/after run: 1/1
# lasted = 38.3 min
#
# For run from 2022-01-21 16:54:44:
# run_id = 1
# before/after run: 0/0
# lasted = 10.8 min
#
# For run from 2022-01-21 17:09:30:
# run_id = 0
# before/after run: 1/1
# lasted = 3.9 min
#
# For run from 2022-01-21 17:13:56:
# run_id = 1
# before/after run: 0/0
# lasted = 12.3 min
#
# For run from 2022-01-21 17:27:12:
# run_id = 0
# before/after run: 1/1
# lasted = 6.1 min
#
# For run from 2022-01-21 17:41:13:
# run_id = 1
# before/after run: 0/0
# lasted = 9.1 min
#
# For run from 2022-01-21 17:54:43:
# run_id = 0
# before/after run: 1/6703
# lasted = 15.4 min
#
# For run from 2022-01-28 11:04:39:
# run_id = 1
# before/after run: 6728/0
# lasted = 26.3 min
#
# For run from 2022-01-28 11:31:49:
# run_id = 0
# before/after run: 1/1
# lasted = 2.2 min
#
# For run from 2022-01-28 11:36:36:
# run_id = 1
# before/after run: 0/0
# lasted = 69.8 min
#
# For run from 2022-01-28 12:48:29:
# run_id = 0
# before/after run: 1/1
# lasted = 5.0 min
#
# For run from 2022-01-28 12:54:36:
# run_id = 1
# before/after run: 0/0
# lasted = 31.1 min
#
# For run from 2022-01-28 13:27:05:
# run_id = 0
# before/after run: 1/1
# lasted = 4.1 min
#
# For run from 2022-01-28 13:33:12:
# run_id = 1
# before/after run: 0/0
# lasted = 7.5 min
#
# For run from 2022-01-28 14:07:56:
# run_id = 0
# before/after run: 1/6729
# lasted = 236.3 min
#
# For run from 2022-01-31 09:57:24:
# run_id = 1
# before/after run: 6813/6814
# lasted = 478.8 min
#
# For run from 2022-02-01 13:13:54:
# run_id = 0
# before/after run: 6834/6835
# lasted = 213.2 min
#
# For run from 2022-02-03 13:45:00:
# run_id = 1
# before/after run: 6845/6846
# lasted = 258.4 min
#
# For run from 2022-02-04 09:10:46:
# run_id = 0
# before/after run: 6866/6867
# lasted = 0.3 min
#
# For run from 2022-02-08 14:45:46:
# run_id = 0
# before/after run: 6982/1
# lasted = 0.9 min
#
# For run from 2022-02-08 14:48:23:
# run_id = 1
# before/after run: 0/6984
# lasted = 131.2 min
#
# For run from 2022-02-09 15:24:41:
# run_id = 0
# before/after run: 7018/7019
# lasted = 74.6 min
#
# For run from 2022-02-10 13:09:25:
# run_id = 1
# before/after run: 7037/0
# lasted = 45.5 min
#
# For run from 2022-02-10 13:55:30:
# run_id = 0
# before/after run: 1/7038
# lasted = 103.8 min
#
# For run from 2022-02-15 10:49:28:
# run_id = 1
# before/after run: 7051/7052
# lasted = 213.3 min
#
# For run from 2022-02-17 10:49:34:
# run_id = 0
# before/after run: 7053/1
# lasted = 1.5 min
#
# For run from 2022-02-17 10:59:10:
# run_id = 1
# before/after run: 0/0
# lasted = 134.5 min
#
# For run from 2022-02-17 13:14:50:
# run_id = 0
# before/after run: 1/7054
# lasted = 33.9 min
#
# For run from 2022-02-18 13:00:32:
# run_id = 1
# before/after run: 7063/7064
# lasted = 177.0 min
#
# For run from 2022-02-21 14:28:10:
# run_id = 0
# before/after run: 7070/7071
# lasted = 211.5 min
#
# For run from 2022-02-22 13:54:47:
# run_id = 1
# before/after run: 7073/0
# lasted = 86.8 min
#
# For run from 2022-02-22 15:34:29:
# run_id = 0
# before/after run: 1/1
# lasted = 82.8 min
#
# For run from 2022-02-22 16:57:46:
# run_id = 1
# before/after run: 0/0
# lasted = 0.3 min
#
# For run from 2022-02-22 16:58:57:
# run_id = 0
# before/after run: 1/1
# lasted = 0.7 min
#
# For run from 2022-02-22 17:06:08:
# run_id = 1
# before/after run: 0/7074
# lasted = 117.3 min
#
# For run from 2022-02-23 15:15:47:
# run_id = 0
# before/after run: 7089/7090
# lasted = 165.2 min
#
# For run from 2022-02-24 13:45:12:
# run_id = 1
# before/after run: 7108/7109
# lasted = 68.8 min
#
# For run from 2022-02-25 14:07:34:
# run_id = 1
# before/after run: 7110/7111
# lasted = 111.4 min
#
# For run from 2022-04-20 08:52:24:
# run_id = 0
# before/after run: 7805/0
# lasted = 16.0 min
#
# For run from 2022-04-20 12:11:43:
# run_id = 0
# before/after run: 0/1
# lasted = 1.8 min
#
# For run from 2022-04-20 12:22:28:
# run_id = 1
# before/after run: 0/7813
# lasted = 7.6 min
#
# For run from 2022-04-28 10:13:41:
# run_id = 1
# before/after run: 7919/0
# lasted = 78.1 min
#
# For run from 2022-04-28 12:54:40:
# run_id = 0
# before/after run: 1/1
# lasted = 71.0 min
#
# For run from 2022-04-28 14:09:17:
# run_id = 1
# before/after run: 0/7959
# lasted = 139.5 min
#
# For run from 2022-05-05 09:43:10:
# run_id = 0
# before/after run: 8140/8177
# lasted = 331.9 min
#
# For run from 2022-05-30 14:35:20:
# run_id = 1
# before/after run: 8529/8550
# lasted = 164.6 min
#
# For run from 2022-06-07 18:19:30:
# run_id = 0
# before/after run: 8732/1
# lasted = 11.2 min
#
# For run from 2022-06-07 18:31:20:
# run_id = 1
# before/after run: 0/0
# lasted = 1.1 min
#
# For run from 2022-06-07 18:34:21:
# run_id = 0
# before/after run: 1/1
# lasted = 6.4 min
#
# For run from 2022-06-07 18:46:16:
# run_id = 1
# before/after run: 0/8733
# lasted = 2.4 min
#
# For run from 2022-06-13 11:22:13:
# run_id = 0
# before/after run: 8778/1
# lasted = 108.8 min
#
# For run from 2022-06-14 08:22:06:
# run_id = 1
# before/after run: 0/0
# lasted = 98.8 min
#
# For run from 2022-06-14 11:45:01:
# run_id = 0
# before/after run: 1/1
# lasted = 320.1 min
#
# For run from 2022-06-15 13:08:00:
# run_id = 1
# before/after run: 0/0
# lasted = 193.6 min
#
# For run from 2022-06-17 09:31:33:
# run_id = 0
# before/after run: 1/1
# lasted = 17.4 min
#
# For run from 2022-06-17 10:18:24:
# run_id = 1
# before/after run: 0/0
# lasted = 2.9 min
#
# For run from 2022-06-17 10:22:10:
# run_id = 0
# before/after run: 1/1
# lasted = 2.2 min
#
# For run from 2022-06-17 20:43:08:
# run_id = 1
# before/after run: 0/1
# lasted = 0.8 min
#
# For run from 2022-06-17 20:44:33:
# run_id = 1
# before/after run: 1/8780
# lasted = 1.2 min
#
# For run from 2022-06-29 14:03:44:
# run_id = 1
# before/after run: 8959/0
# lasted = 2.4 min
#
# For run from 2022-06-29 14:21:22:
# run_id = 0
# before/after run: 1/8965
# lasted = 39.9 min
#
# For run from 2022-07-28 14:25:27:
# run_id = 1
# before/after run: 9031/0
# lasted = 12.3 min
#
# For run from 2022-07-28 14:40:08:
# run_id = 0
# before/after run: 1/1
# lasted = 1.8 min
#
# For run from 2022-07-28 14:45:26:
# run_id = 1
# before/after run: 0/9041
# lasted = 5.7 min

# %%
for i in range(len(records_tcu[:])):
    
    rec = records_tcu[i]
    run_1 = rec["run_number"]
    if run_1 == 0 or run_1 == 1 and run_1 != np.nan:
        stime = datetime.utcfromtimestamp(rec["tstart"]).replace(microsecond=0)
        
        tstart, tstop = datetime.utcfromtimestamp(rec["tstart"]), datetime.utcfromtimestamp(rec["tstop"])
        delta = (tstop - tstart).total_seconds()/60
        a, b = records_caco[i-1]["run_number"], records_caco[i+1]["run_number"]
        kind = rec["kind"]
        print(f"\nFor run from {stime}:\nrun_id = {run_1}\nbefore/after run: {a}/{b}\nlasted = {delta:.1f} min")
        print(f"run type: {kind}")
# Out:
# For run from 2022-06-19 23:22:03:
# run_id = 0
# before/after run: 4084/4086
# lasted = 1.7 min
# run type: calib_drs4
#
# For run from 2022-06-19 23:29:36:
# run_id = 0
# before/after run: 4085/4087
# lasted = 1.8 min
# run type: calib_ped_run
#
# For run from 2022-10-16 20:38:08:
# run_id = 0
# before/after run: 4517/4519
# lasted = 1.7 min
# run type: calib_drs4

# %%
a = datetime.utcfromtimestamp(ticks[0])
str(a)[:-12]
# Out:
# '2022-04'

# %%
for record in records_tcu[:100]:
    
    tstart = round_s(datetime.utcfromtimestamp(record["tstart"]))
    tstop  = round_s(datetime.utcfromtimestamp(record["tstop"]))
    
    run_dict_caco = [rec for rec in records_caco if round_s(datetime.fromisoformat(rec["start_time"][:-1])) == tstart]

    if len(run_dict_caco) > 0:

        c += 1
        print(run_dict_caco[0]["run_number"])
        
        record["run_number"] = run_dict_caco[0]["run_number"]
    else:
        print("----")
# Out:
# 6705
# 6706
# ----
# 6708
# 6709
# 6710
# 6711
# ----
# ----
# ----
# ----
# 6732
# 6733
# 6734
# 6735
# 6736
# ----
# 6738
# 6739
# 6740
# ----
# 6742
# 6743
# 6744
# ----
# 6746
# 6747
# 6748
# 6749
# ----
# 6751
# 6752
# ----
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# ----
# 6763
# 6764
# 6765
# 6766
# 6767
# ----
# ----
# 6770
# 6771
# 6772
# 6773
# 6774
# 6775
# 6776
# 6777
# 6778
# 6779
# 6780
# 6781
# 6782
# 6783
# 6784
# ----
# ----
# ----
# 6789
# 6790
# 6791
# 6792
# 6793
# ----
# 6795
# ----
# ----
# 6798
# 6799
# 6800
# 6801
# ----
# 6803
# 6804
# ----
# 6806
# 6807
# ----
# 6809
# 6810
# 6811
# 6812
# 6815
# 6816
# ----
# ----
# 6819
# 6820
# 6821
# 6822
# ----

# %%
[r for r in records_caco if r["run_number"] == rr][0]["start_time"]
# Out:
# '2022-01-21T20:04:20.177Z'

# %%
rr = 6707

print(datetime.fromisoformat([r for r in records_caco if r["run_number"] == rr][0]["start_time"][:-1]))
# print(round_s(datetime.utcfromtimestamp([records_tcu.index(r) for r in records_tcu if r["run_number"] == rr][0]["tstart"])))

print(datetime.utcfromtimestamp(records_tcu[2]["tstart"]))
# Out:
# 2022-01-21 20:26:14.041000
# 2022-01-21 20:26:15.093433

# %%
rr = 6707

print(datetime.fromisoformat([r for r in records_caco if r["run_number"] == rr][0]["stop_time"][:-1]))
# print(round_s(datetime.utcfromtimestamp([records_tcu.index(r) for r in records_tcu if r["run_number"] == rr][0]["tstart"])))

print(datetime.utcfromtimestamp(records_tcu[2]["tstop"]))
# Out:
# 2022-01-21 20:28:39.765000
# 2022-01-21 20:28:05.269878

# %%
rr = 6707

round_s(datetime.fromisoformat([r for r in records_caco if r["run_number"] == rr][0]["start_time"][:-1]))
# Out:
# datetime.datetime(2022, 1, 21, 20, 26, 10)

# %%
round_s(datetime.fromisoformat(records_caco[105]["start_time"][:-1]))
# Out:
# datetime.datetime(2020, 7, 21, 3, 59)

# %%
for rec in records_tcu:
    try:
        rec["run_number"]
    except KeyError:
        rec["run_number"] = np.nan

# %%
def get_run_num_tcu(recs):
    run_numbers = []
    for rec in recs:
        try:
            run_numbers.append(rec["run_number"])
        except KeyError:
            pass
    return np.array(run_numbers)


run_num_tcu  = get_run_num_tcu(records_tcu)
run_num_caco = np.array([rec["run_number"] for rec in records_caco])

tstart_tcu  = np.array([datetime.utcfromtimestamp(rec["tstart"])       for rec in records_tcu])
tstop_tcu   = np.array([datetime.utcfromtimestamp(rec["tstop"])        for rec in records_tcu])
tstart_caco = np.array([datetime.fromisoformat(rec["start_time"][:-1]) for rec in records_caco])
tstop_caco  = np.array([datetime.fromisoformat(rec["stop_time"][:-1])  for rec in records_caco])

deltat_tcu = tstop_tcu - tstart_tcu
deltat_caco = tstop_caco - tstart_caco

# %%
higher_run = max(np.nanmax(run_num_caco), np.nanmax(run_num_tcu))

for run in np.arange(higher_run+1)[-1000:-990]:
    
    run_dict_caco = [rec for rec in records_caco if rec["run_number"] == run]
    isincaco = len(run_dict_caco) > 0
    
    run_dict_tcu = [rec for rec in records_tcu if rec["run_number"] == run]
    isintcu = len(run_dict_tcu) > 0

    if isincaco and isintcu:
        col = "92"
    elif isincaco or isintcu:
        col = "93"
    else:
        col = "91"
        
    if isintcu:
        end = "type --> "+run_dict_tcu[0]["kind"]
    else:
        end = ""
    if len(run_dict_tcu) == 2:
        end = end + " - 2 same run_num TCU runs!!!!!"
    
    print(f"\033[{col}mRun {run}  inCaCo: {isincaco} \tinTCU: {isintcu}\t{end}")
    
    try:
        T = round_s(datetime.utcfromtimestamp(run_dict_tcu[0]["tstart"]))
    except:
        T=0
    
    print(round_s(datetime.fromisoformat(run_dict_caco[0]["start_time"][:-1])), ' -- ',T, ' --> ',round_s(datetime.fromisoformat(run_dict_caco[0]["start_time"][:-1])) == T)

# %%
plt.scatter([t.timestamp() for t in tstart_caco], 
            [d.total_seconds() for d in deltat_caco], 
            marker=".")
plt.scatter([t.timestamp() for t in tstart_tcu], 
            [d.total_seconds() for d in deltat_tcu], 
            marker=".")
plt.show()

# %%
plt.hist([d.total_seconds()/3600 for d in deltat_tcu], 100);
plt.hist([d.total_seconds()/3600 for d in deltat_caco], 100);

# %%
import datetime
datetime.datetime.fromtimestamp(1643933651.8415616)

# %%
mongo_client = pymongo.MongoClient('localhost:27017')

db = mongo_client['lst1_obs_summary']
# col = db["RUN_INFORMATION"]


# # query = dict()

# # query.update({"tstart": {"$gte": datetime.datetime.fromisoformat(tstart).timestamp()}})
# # query.update({"tstop": {"$lte": datetime.datetime.fromisoformat(tstop).timestamp()}})

# response = col.find()


# records = tuple(
#     doc for doc in response
# )

# %%
db.list_collection_names()

# %%
mongo_client.list_database_names()

# %%
records[0]

# %%
records[1001]["config"]["caco"][0].keys()

# %%
{
  "run_number": 2103,
  "start_time": "2020-06-18T02:44:37.585Z",
  "stop_time": "2020-06-18T02:45:02.742Z",
  "tib": {
    "DigitalPedestalConfigRate": 0,
    "AnalogPedestalEnable": false,
    "PedestalRate": 0.0,
    "CameraRate": 1868.0,
    "FakeTriggerEnable": false,
    "PeriodicPedestalFrequency": 0,
    "PedestalEnable": false,
    "PeriodicPedestalEnable": false,
    "valid": true,
    "LocalRate": 2167.0,
    "SoftwareTriggerEnable": false,
    "DelayLocal": 0.0,
    "SlowControlEnable": false,
    "CalibrationRate": 0.0,
    "MonoEnable": false,
    "BUSYRate": 34.0,
    "CollectedRate": 1902.0,
    "InputMask": 0,
    "CalibrationEnable": false,
    "DigitalPedestalEnable": false,
    "AnalogPedestalThreshold": 0.0,
    "SoftwareTriggerRate": 0.0
  },
  "cbox": {
    "valid": true,
    "hz": "No available",
    "wheel1_position": "No available",
    "temperature": "No available",
    "duty": "No available",
    "humidity": "No available",
    "wheel2_position": "No available",
    "cycles": "No available"
  }
}

# %% [markdown]
# * Run number
# * Time start/stop
# * Kind of run data_takin/calib_drs4...
# * configuration used
#     * camera
#     * caco
#         * Name of command
#         * data - xml file
#         * application time
#     * cbox
# * health
#     * local rate
#         * min/max/mean
#     * anode_current
#         * min/max/mean
